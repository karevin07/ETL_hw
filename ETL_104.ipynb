# %% [markdown]
# # 104 爬蟲

# %%
import requests
import json
import re
import csv
from bs4 import BeautifulSoup
import time

job_url = 'https://www.104.com.tw/jobs/search/?ro=0&keyword={}&order=1&asc=0&kwop=7&page={}'

DATA_PATH = '/tmp/hw_data'
filelist = []
words = []

# %% [markdown]
# # 抓出單頁

# %%
def get_list_page(url):
    
    HOST = 'https:'
    resp = requests.get(url)
    links = links = re.findall('<a href="(//www.104.com.tw/job/.+)" class.+ .+>.+</a>', resp.text)
    detail_page_links = [HOST + link for link in links]
    return detail_page_links

# %%
# !mkdir /tmp/hw_data

# %%
! rm -r -f /tmp/hw_data

# %%
def dump_page(url):  
    filename = re.split('&|\?|=',url)[2]
    resp = requests.get(url)
    with open(DATA_PATH + '/' + filename, 'w') as f:
        f.write(resp.text)
    return filename

# %%
def get_list(url):
    filename = re.split('&|\?|=',url)[2]
    filelist.append(filename)

# %%
def do_page(num1 ,a):   
    print('職缺 '+a)
    print('共抓'+str(num1)+'頁')
    count = 0
    filelist = []
    start = time.time()
    for page in range(num1) :
        the_url = job_url.format(a,page+1)
        for link in get_list_page(the_url):
            dump_page(link)
            count+=1
            get_list(link)
    end = time.time()
    elapsed = end - start
    print('共'+str(count)+'筆職缺')
    print("花費", elapsed, "秒")

# %%
do_page(20,'軟體工程師')
# Out:
# 職缺 軟體工程師
# 共抓20頁
# 共410筆職缺
# 花費 93.75961637496948 秒

# %%
! ls /tmp/hw_data
# Out:
# 28p1c  35xqc  43pgg  4dsad  4nfvi  4yz5r  582jb  5f29d	5mfzh  5tit2  5wree
# 2ews9  36620  44imt  4ebad  4q8ly  4znnf  585ij  5f78p	5nfzu  5tnmj  5xbuk
# 2qw2f  3ax0t  47bi4  4ef7t  4rnpt  4znnq  58it4  5fdfv	5nr43  5tuk3  5xgmx
# 2sqfc  3ayuo  48oy7  4g2hs  4twky  4znol  5aips  5i7gs	5o2v7  5uu9v  5xgn4
# 2xkxg  3s74g  49j0s  4gv6h  4uo4p  4znqs  5clvd  5ja44	5osz2  5v0qj  5xjuj
# 2yiew  3tqo4  4ascb  4i2de  4v29o  4znza  5cxh7  5jh3j	5p3uo  5vuow  5xopg
# 30ai5  3tv8o  4beqa  4io8s  4vvim  524ml  5df6t  5jwzl	5pz7v  5w008  5xq75
# 3421a  3z7ki  4bpwz  4j5ye  4vwwk  53zs5  5e76l  5kj10	5sr1i  5w3id  5xsvc
# 3465n  3zofe  4bpx0  4lbk3  4x9on  56kni  5eewu  5lgr6	5t0hr  5wjdn  5xx42
# 35m14  43olh  4cb8q  4lgy0  4yxnu  57b8b  5emus  5lswi	5tdky  5wn5l  kzfr

# %%
filelist
# Out:
# ['4ns2k',
#  '3nqxv',
#  '5s3zv',
#  '5dsgh',
#  '5wkky',
#  '5gc1i',
#  '5gc2q',
#  '4yz5r',
#  '50oht',
#  '5wv57',
#  '5gj2x',
#  '3s7ws',
#  '5t243',
#  '2i8ys',
#  '4rcg4',
#  '3ofs9',
#  '4zx6g',
#  '5xchy',
#  '5ku83',
#  '4uqkt',
#  '5vjwn',
#  '5wfql',
#  '3a9eq',
#  '52rvg',
#  '4jph4',
#  '5j2yp',
#  '5gie5',
#  '5tgrz',
#  '4njpj',
#  '3hmsz',
#  '44e1n',
#  '51c3d',
#  '5wwwd',
#  '5wdnz',
#  '5vjnx',
#  '4j8xp',
#  '5esf9',
#  '5u98c',
#  '5iv7a',
#  '42lxs',
#  '5t0lb',
#  '4i5ui',
#  '5j0u6',
#  '5xrjc',
#  'x3lm',
#  '5xn6c',
#  '56qox',
#  '5bpur',
#  '5xelw',
#  '5xno9',
#  '5vdn7',
#  '4pfwg',
#  '5dxvg',
#  '5llzv',
#  '5qf26',
#  '2k63f',
#  '5uhr7',
#  '5p5ac',
#  '5xoxh',
#  '4asz4',
#  '2hoak',
#  '5q93c',
#  '5uwz4',
#  '4292r',
#  '4yv12',
#  '3nurl',
#  '5j058',
#  '4l1r2',
#  '5vez3',
#  '4z095',
#  '4i6ed',
#  '5eqtk',
#  '5gxb8',
#  '4nmgv',
#  '4b3fb',
#  '3t94d',
#  '4dc5l',
#  '4qgxn',
#  '2x03m',
#  '55pr5',
#  '4eqod',
#  '4meuy',
#  '4oh68',
#  '5puhp',
#  '4s89i',
#  '4vt9i',
#  '5xssc',
#  '4nxot',
#  '34wdi',
#  '5puuo',
#  '5xkbv',
#  '51ndq',
#  '5u4v9',
#  '43bel',
#  '5k5js',
#  '5k911',
#  '4kyav',
#  '4lpll',
#  '4k086',
#  '5n2mz',
#  '3116c',
#  '5asov',
#  '5w0z4',
#  '5xxuc',
#  '5d6ug',
#  '5by7z',
#  '4uq5w',
#  '5gy5b',
#  '2wwz7',
#  '4r60j',
#  '4w1ba',
#  '2eu03',
#  '5dxq0',
#  '5iabo',
#  '22u8x',
#  '3cbxm',
#  '2k0nv',
#  '5nuai',
#  '5mjz5',
#  'tma3',
#  '5n0jn',
#  '4x6h8',
#  '5wab9',
#  '58ueq',
#  '4g0ms',
#  '31fdd',
#  '362ps',
#  '4o3rl',
#  '5a9ne',
#  '5u4kg',
#  '518cm',
#  '5pz9x',
#  '5s2xg',
#  '5webf',
#  '5duv5',
#  '5dryq',
#  '5k0cp',
#  '5un5f',
#  '5vl69',
#  '3vo3o',
#  '5i0vt',
#  '5at5n',
#  '5ubzi',
#  '5x7gc',
#  '3lj5f',
#  '4kc23',
#  '5dhx7',
#  '572x8',
#  '5h71v',
#  '5rrpz',
#  '5mc9u',
#  '4u9b5',
#  '5wlwd',
#  '4zvg7',
#  '42b2b',
#  '4nxai',
#  '5jjug',
#  '5cyc2',
#  '4jy3z',
#  '5xmml',
#  '3xlph',
#  '3ooqz',
#  '5vh19',
#  '5b4cj',
#  '4qoje',
#  '5ap40',
#  '4yf9g',
#  '5vths',
#  '4485h',
#  '33f33',
#  '5w6uh',
#  '5ophe',
#  '5u0kr',
#  '5hymb',
#  '5whd1',
#  '581ad',
#  '3uzm3',
#  '4w31g',
#  '4kl4y',
#  '5b4f5',
#  '5que3',
#  '2huwr',
#  '3senk',
#  '511qz',
#  '4z06y',
#  '2k0nz',
#  '3nbpu',
#  '42g5r',
#  '5kw71',
#  '5s82o',
#  '5gyuz',
#  '31m2o',
#  '57tda',
#  '5gxqb',
#  '5sv9r',
#  '5ne9o',
#  '5qmom',
#  '44h36',
#  '4f0mw',
#  '33cai',
#  '5bsgp',
#  '5cxpt',
#  '3o7o1',
#  '4xuhl',
#  '5nbq2',
#  '3k1s5',
#  '5m5t4',
#  '5vj8e',
#  '50gfs',
#  '5m8d9',
#  '5udhc',
#  '5xfp1',
#  '31kwc',
#  '3udyb',
#  '3myor',
#  '5iedg',
#  '4mca6',
#  '4pd2o',
#  '56t2j',
#  '57ias',
#  '4jfr5',
#  '5xgif',
#  '4ouzn',
#  '4d7lx',
#  '5h0gn',
#  '5xfxa',
#  '5wtgd',
#  '5fi5u',
#  '5tn1r',
#  '5e8jz',
#  '5uz7m',
#  '5xq95',
#  '4d6c4',
#  '3zc91',
#  '5mdy7',
#  '57ox4',
#  '5srtn',
#  '56nmj',
#  '5vugd',
#  '3ylvq',
#  '4mqej',
#  '3cbui',
#  '4mjv2',
#  '5ephc',
#  '4w1n8',
#  '5u0yi',
#  '49vwe',
#  '46v5a',
#  '57lz2',
#  '2xj0b',
#  '4q0h2',
#  '5sk35',
#  '4ot4y',
#  '3xyxy',
#  '389xi',
#  '4a2ps',
#  '4o7x5',
#  '4cfig',
#  '52yn0',
#  '5gyo4',
#  '5uslb',
#  '5a8gp',
#  '4h3ez',
#  '597i6',
#  '3j48o',
#  '5dob5',
#  '4wzf3',
#  '50ldv',
#  '52r2s',
#  '5lmay',
#  '50by3',
#  '5x8fi',
#  '4jfm1',
#  '3o7r7',
#  '40e3e',
#  '40lop',
#  '40lp1',
#  '40lp5',
#  '58x88',
#  '5v2nt',
#  '3s8n8',
#  '30ya2',
#  '3rykl',
#  '5uus4',
#  '3gxte',
#  '3tf8e',
#  '5jrfg',
#  '5quzz',
#  '4fwhm',
#  '5wgox',
#  '41p2w',
#  '4ei7h',
#  '5pvka',
#  '5xafr',
#  '5u4sx',
#  '5t7qa',
#  '5vh24',
#  '5wxhn',
#  '5xjwb',
#  '4ot2j',
#  '5153n',
#  '51bvh',
#  '38sx2',
#  '5baye',
#  '56yw4',
#  '464q9',
#  '5j962',
#  '41n09',
#  '5iqcb',
#  '5qda8',
#  '5v4cc',
#  '5x9kd',
#  '5p4p2',
#  '3n7xt',
#  '406k0',
#  '4eddf',
#  '5vyu8',
#  '57mpi',
#  '4ugrb',
#  '3u39t',
#  '5rz2n',
#  '4ylgu',
#  '5kusy',
#  '4ucr5',
#  '5aa3c',
#  '5jdoq',
#  '5cloq',
#  '5k7ty',
#  '5s9n9',
#  '2khsz',
#  '4l3vm',
#  '5oxax',
#  '3bbba',
#  '5juji',
#  '2u0a8',
#  '430qf',
#  '4kil6',
#  '5sg8n',
#  '5oyc8',
#  '5quzy',
#  '5t0uc',
#  '5wh1l',
#  '40orc',
#  '5ghgm',
#  '5jd38',
#  '4qi7d',
#  '5l5ug',
#  '5d19b',
#  '5q3bq',
#  '4xyvf',
#  '5vujx',
#  '5ss27',
#  '1y2qr',
#  '3k7hu',
#  '5iqbe',
#  '3psty',
#  '3zgos',
#  '5uhjm',
#  '5o9jy',
#  '4bybi',
#  '5telq',
#  '5izv8',
#  '4nel1',
#  '5xy7z',
#  '4mbky',
#  '5xy7w',
#  '4f6su',
#  '4tlgn',
#  '3u5mp',
#  '3xot1',
#  '5rer8',
#  '5o0q7',
#  '54sc1',
#  '32jka',
#  '3c441',
#  '5x8dq',
#  '2v4b7',
#  '4hryd',
#  '5bvdt',
#  '5as2s',
#  '5wuoq',
#  '4npki',
#  '5gmgb',
#  '4qt2x',
#  '4vlzj',
#  '5x8vl',
#  '51lod',
#  '5tvmb',
#  '5hub8',
#  '5ge6m',
#  '51wmb',
#  '5eu1j',
#  '3vpf3',
#  '5xcid',
#  '5sr77',
#  '4ja4p',
#  '5x1le',
#  '2yo7x',
#  '5rsj0',
#  '4fnea',
#  '3ct10',
#  '5r42o',
#  '5eewp',
#  '5u1bc',
#  '2nglv',
#  '5lwqd',
#  '4tt0a',
#  '4rf55',
#  '5dp3d',
#  '4hryq',
#  '4rk72',
#  '5q2kg',
#  '5xn6m',
#  '5a51x',
#  '5ugkq',
#  '5mjtf',
#  '4uqcm',
#  '4qa1c',
#  '2dtq7',
#  '5xrra',
#  '59rl2',
#  '5ug7t',
#  '5jhuk',
#  '4mpis',
#  '5a4oi',
#  '5kspu',
#  '5j0dq',
#  '3nzw0',
#  '5jytr',
#  '5sy30',
#  '5kscd',
#  '4q9i6',
#  '5cbjd',
#  '5ub9p',
#  '5uwrv',
#  '5l34t',
#  '5lpe6',
#  '5xbsw',
#  '5wxnp',
#  '41jpi',
#  '5malb',
#  '4xht8',
#  '5xnr3',
#  '5pr58',
#  '5bxga',
#  '5vtkm',
#  '323lc',
#  '2meee',
#  '5fsv2',
#  '5xaix',
#  '5rhnc',
#  '519hd',
#  '42okp',
#  '4pbc2',
#  'h88u',
#  '4f0cz',
#  '51l5a',
#  '5sj0h',
#  '5sewe',
#  '4w37t',
#  '4n61n',
#  '5xw3e',
#  '4041f',
#  '5uc7a',
#  '5rtev',
#  '4kuh8',
#  '5j45s',
#  '5v83l',
#  '2ti1i',
#  '5co1q',
#  '480fx',
#  '56klg',
#  '5f4uo',
#  '5wfl0',
#  '4lku2',
#  '5x4h6',
#  '5khjz',
#  '562tw',
#  '5va6n',
#  '5qu7i',
#  '5v7ys',
#  '477v2',
#  '4vyqm',
#  '5pyu8',
#  '46cvo',
#  '5lc8y',
#  '5kmdp',
#  '5r3if',
#  '5u4ja',
#  '4dkss',
#  '4qa1u',
#  '5ukcn',
#  '55r1i',
#  '5vnvr',
#  '31xfp',
#  '5wiz6',
#  '4ki25',
#  '5irl8',
#  '45ix9',
#  '5b9ko',
#  '5lcmi',
#  '5kr3c',
#  '4uw1r',
#  '5ik58',
#  '5vufk',
#  '4r396',
#  '5v2qa',
#  '5xj96',
#  '5rnll',
#  '5xm52',
#  '5xja1',
#  '4g2o4',
#  '5xge8',
#  '5ie2l',
#  '5wuop',
#  '4xgsk',
#  '4ki2w',
#  '4ecdh',
#  '4rk7o',
#  '43d3l',
#  '4wm5x',
#  '2q8z8',
#  '449kw',
#  '5a65b',
#  '426wy',
#  '5wudu',
#  '5vt58',
#  '4jkte',
#  '5msjt',
#  '4ig0l',
#  '5giju',
#  '5sv1h',
#  '3oxhs',
#  '36esg',
#  '3ddq5',
#  '5wxa2',
#  '5h8rt',
#  '5v1zw',
#  '4tuyl',
#  '5w08n',
#  '4ffmk',
#  '5kkxe',
#  '5wd46',
#  '5wukm',
#  '4w578',
#  '5fsm8',
#  '5b7om',
#  '558h1',
#  'res7',
#  '4dla4',
#  '3d6mv',
#  '5pfld',
#  '2nvpi',
#  '5lbet',
#  '5ps06',
#  '524w4',
#  '591v0',
#  '5lmct',
#  '4ifgd',
#  '5xk97',
#  '3w1iv',
#  '5rbqz',
#  '5mz35',
#  '56613',
#  '5dla7',
#  '5mkwp',
#  '5qchg',
#  '56mde',
#  '5p1rp',
#  '2gt66',
#  '5ms4v',
#  '5wurs',
#  '32342',
#  '54olt',
#  '5kvoz',
#  '4217a',
#  '5sqv2',
#  '5tz7v',
#  '2o6zu',
#  '5vo2x',
#  '5sf6n',
#  '4e24e',
#  '5mwhg',
#  '5keom',
#  '5wmls',
#  '4lr3m',
#  '5kj10',
#  '5i33s',
#  '42qvd',
#  '5u1w2',
#  '4ouzx',
#  '5xy8q',
#  '5phlm',
#  '5un08',
#  '5h8rg',
#  '51yyi',
#  '3omw2',
#  '55o7v',
#  '5jkc0',
#  '5vkry',
#  '5dzy9',
#  '266wu',
#  '5r6hf',
#  '5mrv5',
#  '5keyi',
#  '5selv',
#  '5xyj9',
#  '584w2',
#  '58lve',
#  '4h9wm',
#  '4svna',
#  '5lyq0',
#  '5qzv7',
#  '4hn9h',
#  '4cv94',
#  '5rasc',
#  '4q0bc',
#  '5pjsv',
#  '53o5u',
#  'ph5o',
#  '4sbk4',
#  '5ofza',
#  '52evu',
#  '46lbj',
#  '5oby3',
#  '4bdbh',
#  '4z4ck',
#  '5lp59',
#  '5tke7',
#  '4hefh',
#  '4w57o',
#  '5rifx',
#  '5u1so',
#  '4j2zx',
#  '4myfk',
#  '5l25g',
#  '4isra',
#  '5c6vd',
#  '5iniu',
#  '5vudr',
#  '3bbdo',
#  '4dchs',
#  '3pqwv',
#  '28pu7',
#  '37gwp',
#  '5oyhy',
#  '4y1ev',
#  '5pyuj',
#  '57dwx',
#  '5ll0b',
#  '2tlw6',
#  '2s7dx',
#  '57m8h',
#  '4osaa',
#  '5vl7w',
#  '5xo4p',
#  '5uab1',
#  '5obz6',
#  '5lmj5',
#  '5mzgy',
#  '5swr5',
#  '4ud0k',
#  '5xyjw',
#  '2frj1',
#  'ph5h',
#  '5afei',
#  '4u117',
#  '5w2ec',
#  '5r7a2',
#  '5r7al',
#  '5u341',
#  '5u34f',
#  '5sxqp',
#  '5sxqs',
#  '4o70k',
#  '4k3gt',
#  '5noum',
#  '5ouzn',
#  '39my2',
#  'whf9',
#  '4jjpg',
#  '59mw1',
#  '5ours',
#  '43p47',
#  '4xa1d',
#  '5tkd5',
#  '5mjol',
#  '4f84e',
#  '57snk',
#  '4puqc',
#  '4qbrd',
#  '5uq5o',
#  '2s2x1',
#  '5me2r',
#  '2pbwd',
#  '5wff8',
#  '2kod9',
#  '5x1p4',
#  '4qd36',
#  '5do63',
#  'fxbx',
#  '1zfby',
#  '4jpv2',
#  '5vk98',
#  '4rjz2',
#  '5uafk',
#  '3ecxv',
#  '4tzf1',
#  '4tzh7',
#  '4rpgu',
#  '5we71',
#  '2nc3p',
#  '3wtbp',
#  '5x7h7',
#  '59i5l',
#  '5ofjx',
#  '5oail',
#  '4r4u6',
#  '5rzrs',
#  '5w8l1',
#  '5ush4',
#  '4us8q',
#  '4sjdd',
#  '423xg',
#  '5kzho',
#  '59k3y',
#  '5mbq6',
#  '5ql85',
#  '5mwo6',
#  '5fcd6',
#  '46i28',
#  '43ao0',
#  '4z4iu',
#  '34mv0',
#  '5pbe6',
#  '5wjbc',
#  '5fbgo',
#  '3rc9x',
#  '5p8hn',
#  '5wewu',
#  '55jax',
#  '32xnr',
#  '5x34j',
#  '5rzr4',
#  '5rzrl',
#  '48yl4',
#  '3eyay',
#  '5xnk3',
#  '4io7r',
#  '31msg',
#  '5xo7s',
#  '315no',
#  '5taec',
#  '5tafa',
#  '5dldn',
#  '4ee0u',
#  '5xru3',
#  '4aj0j',
#  '2z4hl',
#  '5wa02',
#  '5kzx7',
#  '58ems',
#  '5nqj6',
#  '5tbxv',
#  '5vdnr',
#  '5x4lp',
#  'rc45',
#  '5qki6',
#  '50iff',
#  '4ns2k',
#  '5p4ow',
#  '5wtvs',
#  '4ns2k',
#  '3nqxv',
#  '5s3zv',
#  '5dsgh',
#  '5wkky',
#  '5gc1i',
#  '5gc2q',
#  '4yz5r',
#  '50oht',
#  '5wv57',
#  '5gj2x',
#  '3s7ws',
#  '5t243',
#  '2i8ys',
#  '4rcg4',
#  '3ofs9',
#  '4zx6g',
#  '5xchy',
#  '5ku83',
#  '4uqkt',
#  '5vjwn',
#  '5wfql',
#  '3a9eq',
#  '52rvg',
#  '4jph4',
#  '5j2yp',
#  '5gie5',
#  '5tgrz',
#  '4njpj',
#  '3hmsz',
#  '44e1n',
#  '51c3d',
#  '5wwwd',
#  '5wdnz',
#  '5vjnx',
#  '4j8xp',
#  '5esf9',
#  '5u98c',
#  '5iv7a',
#  '42lxs',
#  '5t0lb',
#  '4i5ui',
#  '5j0u6',
#  '5xrjc',
#  'x3lm',
#  '5xn6c',
#  '56qox',
#  '5bpur',
#  '5xelw',
#  '5xno9',
#  '5vdn7',
#  '4pfwg',
#  '5dxvg',
#  '5llzv',
#  '5qf26',
#  '2k63f',
#  '5uhr7',
#  '5p5ac',
#  '5xoxh',
#  '4asz4',
#  '2hoak',
#  '5q93c',
#  '5uwz4',
#  '4292r',
#  '4yv12',
#  '3nurl',
#  '5j058',
#  '4l1r2',
#  '5vez3',
#  '4z095',
#  '4i6ed',
#  '5eqtk',
#  '5gxb8',
#  '4nmgv',
#  '4b3fb',
#  '3t94d',
#  '4dc5l',
#  '4qgxn',
#  '2x03m',
#  '55pr5',
#  '4eqod',
#  '4meuy',
#  '4oh68',
#  '5puhp',
#  '4s89i',
#  '4vt9i',
#  '5xssc',
#  '4nxot',
#  '34wdi',
#  '5puuo',
#  '5xkbv',
#  '51ndq',
#  '5u4v9',
#  '43bel',
#  '5k5js',
#  '5k911',
#  '4kyav',
#  '4lpll',
#  '4k086',
#  '5n2mz',
#  '3116c',
#  '5asov',
#  '5w0z4',
#  '5xxuc',
#  '5d6ug',
#  '5by7z',
#  '4uq5w',
#  '5gy5b',
#  '2wwz7',
#  '4r60j',
#  '4w1ba',
#  '2eu03',
#  '5dxq0',
#  '5iabo',
#  '22u8x',
#  '3cbxm',
#  '2k0nv',
#  '5nuai',
#  '5mjz5',
#  'tma3',
#  '5n0jn',
#  '4x6h8',
#  '5wab9',
#  '58ueq',
#  '4g0ms',
#  '362ps',
#  '31fdd',
#  '4o3rl',
#  '5a9ne',
#  '5u4kg',
#  '518cm',
#  '5pz9x',
#  '5s2xg',
#  '5webf',
#  '5duv5',
#  '5dryq',
#  '5k0cp',
#  '5un5f',
#  '5vl69',
#  '3vo3o',
#  '5i0vt',
#  '5at5n',
#  '5ubzi',
#  '5x7gc',
#  '3lj5f',
#  '4kc23',
#  '5dhx7',
#  '572x8',
#  '5h71v',
#  '5rrpz',
#  '5mc9u',
#  '4u9b5',
#  '5wlwd',
#  '4zvg7',
#  '42b2b',
#  '4nxai',
#  '5cyc2',
#  '5jjug',
#  '4jy3z',
#  '5xmml',
#  '3xlph',
#  '3ooqz',
#  '5vh19',
#  '5b4cj',
#  '4qoje',
#  '5ap40',
#  '4yf9g',
#  '5vths',
#  '4485h',
#  '33f33',
#  '5w6uh',
#  '5ophe',
#  '5u0kr',
#  '5hymb',
#  '5whd1',
#  '581ad',
#  '3uzm3',
#  '4w31g',
#  '4kl4y',
#  '5b4f5',
#  '5que3',
#  '2huwr',
#  '3senk',
#  '511qz',
#  '4z06y',
#  '2k0nz',
#  '3nbpu',
#  '42g5r',
#  '5kw71',
#  '5s82o',
#  '5gyuz',
#  '31m2o',
#  '57tda',
#  '5gxqb',
#  '5sv9r',
#  '5ne9o',
#  '5qmom',
#  '44h36',
#  '4f0mw',
#  '33cai',
#  '5cxpt',
#  '5bsgp',
#  '3o7o1',
#  '4xuhl',
#  '5nbq2',
#  '3k1s5',
#  '5m5t4',
#  '5vj8e']

# %% [markdown]
# # 內文清理

# %%
words
# Out:
# ['ASP.NET',
#  'C#',
#  'Visual Studio .net',
#  'MS SQL',
#  'HTML',
#  'JavaScript',
#  'jQuery',
#  '不拘',
#  'C#',
#  '軟體程式設計',
#  '設計機台設備自動化',
#  '不拘',
#  '不拘',
#  '不拘',
#  '不拘',
#  'Excel',
#  'PowerPoint',
#  'Word',
#  '中文打字75~100',
#  '不拘',
#  'Windows 98',
#  'Windows XP',
#  'Windows 7',
#  'Windows Server 2008',
#  'iOS',
#  'Windows 8',
#  'Windows Server 2012',
#  'Vmware',
#  'LAN',
#  'TCP/IP',
#  'WAN',
#  'Excel',
#  'Ghost',
#  'PowerPoint',
#  'Visio',
#  'Word',
#  'WLAN',
#  '作業系統基本操作',
#  '資料備份與復原',
#  '電腦設備裝配',
#  '資訊設備操作檢修',
#  '資訊設備環境設定',
#  '網路資料傳輸',
#  '系統架構規劃與維護',
#  '軟硬體設備預算與採買規劃',
#  '網路配線工具使用',
#  'MS SQL',
#  'MySQL',
#  '不拘',
#  'Java',
#  '不拘',
#  'Matlab',
#  'EMC/EMI',
#  'OrCAD',
#  'SPICE',
#  '信號與系統設計',
#  '電子電路設計',
#  '不拘',
#  '不拘',
#  'Windows 2000',
#  'Windows 2003',
#  'Windows Server 2008',
#  'Windows Server 2012',
#  'Visual Basic .net',
#  'MS SQL',
#  '中文打字20~50',
#  '英文打字20~50',
#  '不拘',
#  'Android',
#  'iOS',
#  'C',
#  'Java',
#  '軟體工程系統開發',
#  '網路資料傳輸',
#  '軟體程式設計',
#  'AJAX',
#  'jQuery',
#  '軟體工程系統開發',
#  '軟體整合測試',
#  '軟體程式設計',
#  '產品或零件測試驗證',
#  '不拘',
#  '不拘',
#  '不拘',
#  '不拘',
#  'FreeBSD',
#  'Linux',
#  'Windows 2000',
#  'C',
#  'C++',
#  'Java',
#  'PHP',
#  'Python',
#  'MySQL',
#  'JavaScript',
#  'CVS',
#  '不拘',
#  'ASP.NET',
#  'C#',
#  'Java',
#  'JSP',
#  'Visual Basic .net',
#  'Visual C#',
#  'Visual Studio .net',
#  '軟體程式設計',
#  '資料庫程式設計',
#  'ASP.NET',
#  'C#',
#  'Visual Studio',
#  'MS SQL',
#  '軟體工程系統開發',
#  '資料庫程式設計',
#  '不拘',
#  '不拘',
#  'C#',
#  'Visual C++',
#  '軟體程式設計',
#  '網路程式設計',
#  '不拘',
#  '不拘',
#  'Windows Server 2008',
#  'Windows 8',
#  'Windows Server 2012',
#  'ASP',
#  'ASP.NET',
#  'C++',
#  'Visual Basic',
#  'Visual C#',
#  'Visual C++',
#  '軟體工程系統開發',
#  '韌體工程開發',
#  '軟體程式設計',
#  '結構化程式設計',
#  '模組化系統設計',
#  'C',
#  'C#',
#  'C++',
#  'Java',
#  'PHP',
#  'Python',
#  'Visual C#',
#  'Visual C++',
#  'Visual Studio',
#  'Objective-C',
#  'SWIFT',
#  'R',
#  '網路資料傳輸',
#  '軟體程式設計',
#  '網路程式設計',
#  '資料庫程式設計',
#  '資料庫軟體應用',
#  'C#',
#  'Visual Studio',
#  '不拘',
#  'OOP',
#  'C++',
#  'MFC',
#  '軟體品質與保證',
#  '軟體程式設計',
#  'Apple',
#  'Android',
#  'C++',
#  '軟體工程系統開發',
#  '韌體工程開發',
#  '軟體程式設計',
#  '韌體程式設計',
#  '模組化系統設計',
#  'Linux',
#  'Windows 7',
#  'Windows 8',
#  'C#',
#  'MySQL',
#  'XML Web services',
#  'HTTP',
#  'Socket',
#  'TCP/IP',
#  'UDP',
#  '軟體程式設計',
#  '結構化程式設計',
#  '網路程式設計',
#  '模組化系統設計',
#  '不拘',
#  '不拘',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Project',
#  'Word',
#  '韌體工程開發',
#  '無線通訊技術開發',
#  '整合無線通訊模組',
#  '軟體程式設計',
#  '韌體程式設計',
#  '撰寫硬體語言程式',
#  '數位晶片產品開發',
#  '不拘',
#  '不拘',
#  '不拘',
#  '不拘',
#  'Linux',
#  'C',
#  'C++',
#  '不拘',
#  'OOAD',
#  'OOP',
#  'ASP.NET',
#  'C#',
#  'MS SQL',
#  'MySQL',
#  'Oracle',
#  '不拘',
#  '不拘',
#  '不拘',
#  '不拘',
#  '不拘',
#  'C#',
#  'Java',
#  'Visual Basic .net',
#  'Visual Studio .net',
#  'MS SQL',
#  'MySQL',
#  'Oracle',
#  '不拘',
#  'C#',
#  'Java',
#  'Visual Basic .net',
#  'Visual Studio .net',
#  'MS SQL',
#  'MySQL',
#  'Oracle',
#  '不拘',
#  'Linux',
#  'C',
#  'C++',
#  'Perl',
#  'PHP',
#  'HTML',
#  'JavaScript',
#  '不拘',
#  'C',
#  'C++',
#  '軟體程式設計',
#  '網路程式設計']

# %%
len(words)
# Out:
# 243

# %%
#讀內文

for l in filelist:
    with open(DATA_PATH + '/' + l) as f:
        html = f.read()
        soup = BeautifulSoup(html, 'lxml')
        data = soup.find_all('dd',{'class':'tool'})
        for a in range(len(data)):
            words.extend(data[a].text.split('、'))
filelist = []

# %%
#建技能表
with open('skill104.txt') as sk:
    skilllist =  sk.read()
skill = skilllist.split('\n')
skill.remove('')

# %%
# 計次歸零
counter = {}
for b in skill:
    counter[b]=0

# %%
# 計次
def get_skill(list):    
    for b in skill:
        counter[b] += 0
    for a in range(len(list)):
        word = list[a]
        if word in skill:                            
            counter[word]+=1
    return counter

# %%
dictskill = get_skill(words)

# %%
countskill = sorted(dictskill.items(),key = lambda item:item[1],reverse=True)

# %% [markdown]
# # 輸出Json 、 CSV

# %%
def get_json(dict,file):
    with open(file, 'w') as f:
        json.dump(dict,f)

# %%
def get_csv(dict,file):
    with open(file,'w') as f:
        w=csv.writer(f)
        # write all keys on one row and all values on the next
        w.writerow(dict.keys())
        w.writerow(dict.values())

# %%
def get_tupletocsv(list,file):

    with open(file,'w') as out:
        csv_out=csv.writer(out)
        csv_out.writerow(['技能','數量'])
        for row in list:
            csv_out.writerow(row)

# %%
get_tupletocsv(countskill,'104軟體工程師.csv')

# %%
words = []

# %%
import matplotlib.pyplot as plt
import pandas as pd # 引用套件並縮寫為 pd
